# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import seaborn as sns # for staticals graphics
import matplotlib.pyplot as plt #for plotting
import warnings # to show warning to users
warnings.filterwarnings("ignore")
from sklearn.datasets import load_iris
from statsmodels.stats.weightstats import ttest_ind
import missingno as msno
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\nekei\OneDrive\Documents\DeathCausesReasons.csv")
print (df)
# Out:
#     Country Name  Covid-19 Deaths  Cardiovascular diseases  \
# 0    Afghanistan           2201.0                    61995
# 1        Albania           1181.0                    12904
# 2        Algeria           2762.0                    97931
# 3        Andorra             84.0                      169
# 4         Angola             33.0                    25724
# ..           ...              ...                      ...
# 186      Vietnam             35.0                   240161
# 187        Wales            512.0                    10519
# 188        Yemen            610.0                    55752
# 189       Zambia            390.0                    18157
# 190     Zimbabwe            369.0                    17810
#
#      Respiratory diseases   Kidney diseases  Neonatal disorders   Meningitis   \
# 0                     7082             5637                23701         1563
# 1                      815              329                  161           13
# ...

# %%
cardio= df['Cardiovascular diseases']
country_names = df['Country Name']
neoplasms = df ['Neoplasms']
resp = df['Respiratory diseases ']
digestive = df ['Digestive diseases']
low_resp_infe= df ['Lower respiratory infections']

america = df.loc[[182]]
nieu = df.loc[[121]]
india = df.loc[[75]]
nigeria = df.loc[[120]]
china = df.loc[[35]]
brazil = df.loc [[24]]
nauru = df.loc[[114]]
norway = df.loc[[125]]

pd.set_option('display.float_format', lambda x: '%0.2f' % x)

# %%
df.head
# Out:
# <bound method NDFrame.head of     Country Name  Covid-19 Deaths  Cardiovascular diseases  \
# 0    Afghanistan          2201.00                    61995
# 1        Albania          1181.00                    12904
# 2        Algeria          2762.00                    97931
# 3        Andorra            84.00                      169
# 4         Angola            33.00                    25724
# ..           ...              ...                      ...
# 186      Vietnam            35.00                   240161
# 187        Wales           512.00                    10519
# 188        Yemen           610.00                    55752
# 189       Zambia           390.00                    18157
# 190     Zimbabwe           369.00                    17810
#
#      Respiratory diseases   Kidney diseases  Neonatal disorders   Meningitis   \
# 0                     7082             5637                23701         1563
# ...

# %%
list(df.columns.values.tolist()) #Shows all death causes
sorted(df) #Alphabetical order
# Out:
# [' Acute hepatitis',
#  " Alzheimer's disease",
#  ' Cirrhosis and other chronic liver diseases',
#  ' Conflict and terrorism',
#  'Alcohol use disorders',
#  'Cardiovascular diseases',
#  'Country Name',
#  'Covid-19 Deaths',
#  'Diabetes ',
#  'Diarrheal diseases',
#  'Digestive diseases',
#  'Drowning',
#  'Drug use disorders',
#  'Environmental heat and cold exposure',
#  'Fire, heat',
#  'HIV/AIDS',
#  'Interpersonal violence',
#  'Kidney diseases',
#  'Lower respiratory infections',
#  'Malaria ',
#  'Maternal disorders',
#  'Meningitis ',
#  'Neonatal disorders ',
#  'Neoplasms',
#  'Nutritional deficiencies',
#  "Parkinson's disease",
#  'Poisoning',
#  'Protein-energy malnutrition',
#  'Respiratory diseases ',
#  'Road injuries',
#  'Self-harm',
#  'Tuberculosis']

# %%
df.describe() #With this function it is showing the mean, standard deviation , different percentiles including min and max.
# Out:
#        Covid-19 Deaths  Cardiovascular diseases  Respiratory diseases   \
# count           188.00                   191.00                 191.00
# mean          10461.40                 98089.36               21042.42
# std           35107.42                395678.18              116235.26
# min               1.00                     8.00                   1.00
# 25%              84.75                  4648.50                 529.50
# 50%             612.50                 18157.00                2529.00
# 75%            3986.75                 57372.50                7118.00
# max          353948.00               4584273.00             1168381.00
#
#        Kidney diseases  Neonatal disorders   Meningitis   Malaria   \
# count           191.00               191.00       191.00    191.00
# mean           7490.71              9759.51      1217.59   3275.04
# std           24085.22             39729.67      4486.65  15318.49
# ...

# %%
cardio.describe()
# Out:
# count       191.00
# mean      98089.36
# std      395678.18
# min           8.00
# 25%        4648.50
# 50%       18157.00
# 75%       57372.50
# max     4584273.00
# Name: Cardiovascular diseases, dtype: float64

# %%
neoplasms.describe()
# Out:
# count       191.00
# mean      53728.21
# std      219475.54
# min           3.00
# 25%        2183.50
# 50%       10084.00
# 75%       29581.00
# max     2716551.00
# Name: Neoplasms, dtype: float64

# %%
resp.describe()
# Out:
# count       191.00
# mean      21042.42
# std      116235.26
# min           1.00
# 25%         529.50
# 50%        2529.00
# 75%        7118.00
# max     1168381.00
# Name: Respiratory diseases , dtype: float64

# %%
digestive.describe()
# Out:
# count      191.00
# mean     13517.87
# std      42769.72
# min          1.00
# 25%        592.50
# 50%       3226.00
# 75%       8585.50
# max     464914.00
# Name: Digestive diseases, dtype: float64

# %%
low_resp_infe.describe()
# Out:
# count      191.00
# mean     13151.41
# std      38659.05
# min          1.00
# 25%        530.50
# 50%       2454.00
# 75%      12229.50
# max     433661.00
# Name: Lower respiratory infections, dtype: float64

# %%
plt.figure(figsize=(25,3))
sns.boxplot(cardio)
plt.show()

# %%
sns.histplot(cardio)
# Out:
# <AxesSubplot:xlabel='Cardiovascular diseases', ylabel='Count'>

# %%
sns.histplot(cardio, log_scale=True)
# Out:
# <AxesSubplot:xlabel='Cardiovascular diseases', ylabel='Count'>

# %%
sns.histplot(neoplasms)
# Out:
# <AxesSubplot:xlabel='Neoplasms', ylabel='Count'>

# %%
sns.histplot(neoplasms, log_scale=True)
# Out:
# <AxesSubplot:xlabel='Neoplasms', ylabel='Count'>

# %%
sns.histplot(resp)
# Out:
# <AxesSubplot:xlabel='Respiratory diseases ', ylabel='Count'>

# %%
sns.histplot(resp,log_scale=True)
# Out:
# <AxesSubplot:xlabel='Respiratory diseases ', ylabel='Count'>

# %%
sns.histplot(digestive)
# Out:
# <AxesSubplot:xlabel='Digestive diseases', ylabel='Count'>

# %%
sns.histplot(digestive,log_scale=True)
# Out:
# <AxesSubplot:xlabel='Digestive diseases', ylabel='Count'>

# %%
sns.histplot(low_resp_infe)
# Out:
# <AxesSubplot:xlabel='Lower respiratory infections', ylabel='Count'>

# %%
sns.histplot(low_resp_infe,log_scale=True)
# Out:
# <AxesSubplot:xlabel='Lower respiratory infections', ylabel='Count'>

# %%
ttest_ind(resp,low_resp_infe)
# Out:
# (0.8902843007763316, 0.37387654315181384, 380.0)

# %%
df.corr()
# Out:
#                                              Covid-19 Deaths  \
# Covid-19 Deaths                                         1.00
# Cardiovascular diseases                                 0.33
# Respiratory diseases                                    0.34
# Kidney diseases                                         0.55
# Neonatal disorders                                      0.25
# Meningitis                                              0.15
# Malaria                                                -0.01
# Interpersonal violence                                  0.64
# HIV/AIDS                                                0.12
# Tuberculosis                                            0.27
# Maternal disorders                                      0.24
# Lower respiratory infections                            0.43
# Alcohol use disorders                                   0.56
# Diarrheal diseases                                      0.28
# ...

# %%
x = np.sort(digestive)
y = 1* np.arange(len(digestive))/(len(digestive)-1)
plt.plot(x,y)

# %%
df.isnull() #this will show if I am missing data
# Out:
#      Country Name  Covid-19 Deaths  Cardiovascular diseases  \
# 0           False            False                    False
# 1           False            False                    False
# 2           False            False                    False
# 3           False            False                    False
# 4           False            False                    False
# ..            ...              ...                      ...
# 186         False            False                    False
# 187         False            False                    False
# 188         False            False                    False
# 189         False            False                    False
# 190         False            False                    False
#
#      Respiratory diseases   Kidney diseases  Neonatal disorders   Meningitis   \
# 0                    False            False                False        False
# 1                    False            False                False        False
# ...

# %%
sns.catplot(x= country_names , y= low_resp_infe , kind = "swarm",data = df)

# %% [markdown]
# Im not missing any data so thats great since all of them came back false .

# %%
sns.catplot(x=country_names, y= resp , kind = "swarm",data = df)

# %%
df.corr() #this finds correlation between death causes
# Out:
#                                              Covid-19 Deaths  \
# Covid-19 Deaths                                         1.00
# Cardiovascular diseases                                 0.33
# Respiratory diseases                                    0.34
# Kidney diseases                                         0.55
# Neonatal disorders                                      0.25
# Meningitis                                              0.15
# Malaria                                                -0.01
# Interpersonal violence                                  0.64
# HIV/AIDS                                                0.12
# Tuberculosis                                            0.27
# Maternal disorders                                      0.24
# Lower respiratory infections                            0.43
# Alcohol use disorders                                   0.56
# Diarrheal diseases                                      0.28
# ...

# %%
plt.figure(figsize=(16, 16))
# define the mask to set the values in the upper triangle to True
mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))
heatmap = sns.heatmap(df.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':5}, pad=16);

# %% [markdown]
# Stronger correlations in dark blue and weaker is in dark brown but we do noy
# see any negative correlation (darker brown)
# Viewing just this map we can see that
# "Malaria" is not common in alot of countries which has alot to do with regions as well as "Conflict and Terrorism" which I know is top for afghanistan because thats were alot of war take place.

# %%
countries= df.sum(axis=0)[1:].sort_values(ascending=True).index
total_death = df.sum(axis=0)[1:].sort_values(ascending=True).values

print("\033[1m"+"Causes of death (sorted ascending) "+"\033[0m")         
for i in range(0,len(countries)):
    print(countries[i],"=",f'{total_death[i]:,}')     

countries= df.sum(axis=0)[1:].sort_values(ascending=False).index
total_death = df.sum(axis=0)[1:].sort_values(ascending=False).values

print("\033[1m"+"\nTotal death ="+"\033[0m",
     f'{ np.sum(df.sum(axis=0)[1:].sort_values(ascending=False).values) :,}')
# Out:
# Causes of death (sorted ascending)
# Environmental heat and cold exposure = 47,381
#  Conflict and terrorism = 62,594
# Poisoning = 76,684
#  Acute hepatitis = 78,711
# Fire, heat = 110,886
# Drug use disorders = 130,660
# Alcohol use disorders = 169,466
# Maternal disorders = 192,852
# Protein-energy malnutrition = 208,395
# Meningitis  = 232,559
# Drowning = 236,366
# Nutritional deficiencies = 247,638
# Parkinson's disease = 370,490
# Interpersonal violence = 412,055
# Malaria  = 625,532
# Self-harm = 761,569
# HIV/AIDS = 836,303
# Tuberculosis = 1,159,685
# Road injuries = 1,193,057
# Kidney diseases = 1,430,726
#  Cirrhosis and other chronic liver diseases = 1,477,440
# Diarrheal diseases = 1,515,372
# Diabetes  = 1,551,054
#  Alzheimer's disease = 1,655,193
# Neonatal disorders  = 1,864,067
# Covid-19 Deaths = 1,966,744.0
# Lower respiratory infections = 2,511,920
# Digestive diseases = 2,581,914
# Respiratory diseases  = 4,019,102
# Neoplasms = 10,262,088
# ...

# %% [markdown]
# With this we see the total amount of deaths as well as the most common deaths in the world across the board which is "Cardiovascular diseases" being almost two times the amount of the second leading cause which is "Neoplasms".Neoplasms is mainly cancer.

# %%
fig, ax = plt.subplots(figsize =(15, 10))
sns.barplot(total_death,countries)
plt.grid(color='black', linestyle='--', linewidth=.5)
plt.title("Deaths in the world",fontsize=20)
plt.xlabel("Total Deaths (1e^7)",fontsize=20)
plt.show()

# %% [markdown]
# This shows the same idea as the idea above but it gives a better visual of the death rates.

# %%
countries = df.loc[ df["Cardiovascular diseases"].sort_values(ascending=True)[:5].index]["Country Name" ].values
total_death = df["Cardiovascular diseases"].sort_values(ascending=True)[:5].values

print("\033[1m"+"5 countries with the lowest death rates from Cardiovascular diseases"+"\033[0m")         
for i in range(0,len(countries)):
    print(countries[i],"=",f'{total_death[i]:,}')     

countries = df.loc[ df["Cardiovascular diseases"].sort_values(ascending=False)[:5].index]["Country Name" ].values
total_death = df["Cardiovascular diseases"].sort_values(ascending=False)[:5].values

print("\033[1m"+"\n5 countries with the highest death rates from Cardiovascular diseases"+"\033[0m")         
for i in range(0,len(countries)):
    print(countries[i],"=",f'{total_death[i]:,}')  
   
print("\033[1m"+"\nTotal death toll from Cardiovascular diseases ="+"\033[0m",
     f'{ df["Cardiovascular diseases"].sort_values(ascending=False).sum() :,}')
# Out:
# 5 countries with the lowest death rates from Cardiovascular diseases
# Niue = 8
# Nauru = 23
# Tuvalu = 42
# Cook Islands = 58
# Palau = 65
#
# 5 countries with the highest death rates from Cardiovascular diseases
# China = 4,584,273
# India = 2,574,410
# Russia = 1,004,931
# United States = 957,455
# Indonesia = 651,481
#
# Total death toll from Cardiovascular diseases = 18,735,068

# %%
countries = df.loc[ df["Neoplasms"].sort_values(ascending=True)[:5].index]["Country Name" ].values
total_death = df["Neoplasms"].sort_values(ascending=True)[:5].values

print("\033[1m"+"5 countries with the lowest death rates from Neoplasms"+"\033[0m")         
for i in range(0,len(countries)):
    print(countries[i],"=",f'{total_death[i]:,}')     

countries = df.loc[ df["Neoplasms"].sort_values(ascending=False)[:5].index]["Country Name" ].values
total_death = df["Cardiovascular diseases"].sort_values(ascending=False)[:5].values

print("\033[1m"+"\n5 countries with the highest death rates from Neoplasms"+"\033[0m")         
for i in range(0,len(countries)):
    print(countries[i],"=",f'{total_death[i]:,}')  
   
print("\033[1m"+"\nTotal death toll from Neoplasms ="+"\033[0m",
     f'{ df["Neoplasms"].sort_values(ascending=False).sum() :,}')
# Out:
# 5 countries with the lowest death rates from Neoplasms
# Niue = 3
# Nauru = 8
# Tuvalu = 14
# Cook Islands = 32
# Palau = 36
#
# 5 countries with the highest death rates from Neoplasms
# China = 4,584,273
# India = 2,574,410
# United States = 1,004,931
# Japan = 957,455
# Russia = 651,481
#
# Total death toll from Neoplasms = 10,262,088

# %%
causes = list(df.columns)
causes = causes[1:-2]

#Top 10 countries with the highest number of deaths from a given disease
causes_10 = {}
for cause in causes:
    top_ten = df[["Country Name", cause]].sort_values(ascending=False,by=cause)
    causes_10[cause] = top_ten[:10]

for cause in causes[:11]:
    f = plt.figure(figsize=(20, 6))
    sns.barplot(x = "Country Name", y = cause, data = causes_10[cause])
    
gs = f.add_gridspec(6, 6)    
f.tight_layout()

# %% [markdown]
# With this visual it shows the top causes of deaths in each country.

# %%
all_others_covid = df["Covid-19 Deaths"].sort_values(ascending=False)[5:].sum()
total_death = np.append(total_death,all_others_covid)
countries = np.append(countries,"Others")

colors = ( "red", "orange", "yellow",
          "blue", "green", "beige")

wp = { 'linewidth' : 1, 'edgecolor' : "green" }

def func(pct, allvalues):
    absolute = int(pct / 100.*np.sum(allvalues))
    return "{:.2f}%\n({:d})".format(pct, absolute)

fig, ax = plt.subplots(figsize =(10, 10))

wedges, texts, autotexts = ax.pie(total_death,
                                  autopct = lambda pct: func(pct, total_death),
                                  labels = countries ,
                                   explode = [0.15, 0, 0, 0, 0, 0],
                                  shadow = True,
                                  colors = colors,
                                  startangle = 90,)

plt.title("5 countries with the highest death rates from covid-19",fontsize= 30)
plt.legend(title = "Country",loc ="upper right")
plt.show()

# %%
#Top 10 countries of Covid-19 Deaths and the percentage of Covid-19 and others diseases that cause the death in these countries.

def my_autopct(pct):
    return ('%.2f' % pct) if pct > 5 else ''


covid_10 = list(causes_10["Covid-19 Deaths"]["Country Name"])

for country in covid_10:

    causes_death = []
    value = []
    causes_death = list(df[df["Country Name"] == country].columns)
    causes_death = causes_death[1: -2]
    value = df[df["Country Name"] == country].values.tolist()
    value = value[0][1: -2]
    number = value
    per_val = np.array(number)
    percent = 100.*per_val/per_val.sum()
    
    size = 0.4
    plt.figure(figsize=(15, 15))
    patches, texts = plt.pie(number,startangle=90, radius=1 - size, wedgeprops=dict(width=size, edgecolor='w'))  
    labels = ['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(causes_death, percent)]  
  
    sort_legend = True  
    if sort_legend:  
        patches, labels, dummy =  zip(*sorted(zip(patches, labels, number),  
                                              key=lambda causes_death: causes_death[2],  
                                              reverse=True))  
  
    plt.legend(patches, labels, loc='best', bbox_to_anchor=(-0.05, 1), fontsize=12) 
    plt.rcParams['axes.titley'] = 0.8 
    plt.title(country, fontsize=25)
    
    
    plt.show()
